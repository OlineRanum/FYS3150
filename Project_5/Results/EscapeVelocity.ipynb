# %%
import numpy as np 
import os
import seaborn as sns
import matplotlib.pyplot as plt

mypathVel2                  = "/home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5D3/EscapeVel2.txt"
mypathVel3                  = "/home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5D3/EscapeVel3.txt"

mypathVel4                  = "/home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5D3/EscapeVel4.txt"

mypathVel6                  = "/home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5D3/EscapeVel6.txt"
mypathVel7                  = "/home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5D3/EscapeVel7.txt"
mypathVel8                  = "/home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5D3/EscapeVel8.txt"
mypathVel9                  = "/home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5D3/EscapeVel9.txt"
mypathVel10                  = "/home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5D3/EscapeVel10.txt"



test                 = "/home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5D3/EscapeVel2_test.txt"






def read_files(path):  
    
    x, y, z = [],[],[]
    vx, vy, vz = [],[],[]
    t = []
    
    
    with open(path, 'r') as infile:
        lines = infile.readlines()[2:]
        for line in lines:

            line = line.split()
            t.append(float(line[0]))
            x.append(float(line[1]))
            y.append(float(line[2]))
            z.append(float(line[3]))
            vx.append(float(line[4]))
            vy.append(float(line[5]))
            vz.append(float(line[6]))
    
    r = np.zeros((len(x), 3))
    v = np.zeros((len(x), 3))
    for i in range(len(x)):
        r[i] = [x[i], y[i], z[i]]
        v[i] = [vx[i], vy[i], vz[i]]
        
    return t, r, v

tE2, rE2, vE2 = read_files(mypathVel2)
tE3, rE3, vE3 = read_files(mypathVel3)

tE4, rE4, vE4 = read_files(mypathVel4)
tE6, rE6, vE6 = read_files(mypathVel6)
tE7, rE7, vE7 = read_files(mypathVel7)

#tE7, rE7, vE7 = read_files(test)

tE8, rE8, vE8 = read_files(mypathVel8)
tE9, rE9, vE9 = read_files(mypathVel9)
tE10, rE10, vE10 = read_files(mypathVel10)



c1 = 'firebrick'
c2 = 'steelblue'
c3 = 'plum'
c4 = 'seagreen'
c5 = 'orange'

# %%
plt.plot(rE4[:,0], rE4[:,1])

# %%
fig = plt.figure(figsize = (20,15))
ax = plt.axes(projection='3d')
ax.scatter3D(rE7[:,0], rE7[:,1], rE7[:,2], marker = '.', label = 'Euler', linestyle = '-');

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import matplotlib.colors

fig = plt.figure(figsize = (20,15))
ax = plt.axes(projection='3d')

fsize = 40


ax.scatter3D(0,0,0, s = 50, c = 'orange', label = 'The sun')

ax.scatter3D(rE2[:,0], rE2[:,1], rE2[:,2], s = 100, marker = '.', c= 'steelblue', label = '$v_0$ = 2', linestyle = '-');
ax.scatter3D(rE4[:,0], rE4[:,1], rE4[:,2], s = 100, marker = '.', label = '$v_0$ = 4', linestyle = '-');

ax.scatter3D(rE6[:,0], rE6[:,1], rE6[:,2],s = 100, marker = '.', label = '$v_0$ = 6', linestyle = '-');
ax.scatter3D(rE8[:,0], rE8[:,1], rE8[:,2],s = 100, marker = '.', label = '$v_0$ = 8', linestyle = '-');
ax.scatter3D(rE7[:,0], rE7[:,1], rE7[:,2],s = 100, marker = '.', label = '$v_0$ = 7', linestyle = '-');

ax.scatter3D(rE9[:-800,0], rE9[:-800,1], rE9[:-800,2],s = 100,  marker = '.', label = '$v_0$ = 9', linestyle = '-');

ax.scatter3D(rE10[:-800,0], rE10[:-800,1], rE10[:-800,2],s = 100, marker = '.', label = '$v_0$ = 10', linestyle = '-');
#ax.scatter3D(rV[:,0], rV[:,1], rV[:,2], marker = '.', c= c1, label = 'Verlet', linestyle = '-');

#ax.plot3D(rV[:,0], rV[:,1], rV[:,2], c = c1)
#ax.plot3D(rE[:,0], rE[:,1], rE[:,2], 'steelblue')



plt.title('Sun-Earth system, N = $10^6$', pad = 50, fontsize = fsize)
ax.set_xlabel('X [AU]', fontsize = fsize)
ax.set_ylabel('Y [AU]',  fontsize = fsize)
ax.set_zlabel('Z [AU]',  fontsize = fsize)
ax.xaxis.set_tick_params(labelsize=fsize-10, pad = 15)
ax.yaxis.set_tick_params(labelsize=fsize-10, pad = 15)
ax.zaxis.set_tick_params(labelsize=fsize-10, pad = 15)

plt.legend(fontsize = fsize-10, loc = 'upper left')
ax.yaxis.labelpad=100
ax.xaxis.labelpad=100
ax.zaxis.labelpad=85

#ax.set_yticks([-0.75, 0,0.75])
#ax.set_xticks([ -0.75, 0,0.75])
#ax.set_zticks([-0.75, 0,0.75])

#ax.set_xlim([-1.25,1.25])
#ax.set_ylim([-1.25,1.25])
#ax.set_zlim([-1.25,1.25])


#plt.savefig('../Paper/Figures/Escape.png')
