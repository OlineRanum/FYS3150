# %%
import numpy as np 
import os
import seaborn as sns

from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
# %matplotlib inline

mypath0                  = "/home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5F1/Planet_Sun.txt"
mypath1                  = "/home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5F2/Planet_Mercury.txt"
mypath2                  = "/home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5F2/Planet_Venus.txt"
mypath3                  = "/home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5F2/Planet_Earth.txt"
mypath4                  = "/home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5F2/Planet_Mars.txt"
mypath5                  = "/home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5F1/Planet_Jupiter.txt"
mypath6                  = "/home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5F1/Planet_Saturn.txt"
mypath7                  = "/home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5F1/Planet_Uranus.txt"
mypath8                  = "/home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5F1/Planet_Netptun.txt"

pathlist = np.array([mypath0,mypath1,mypath2,mypath3,mypath4,mypath5,mypath6,mypath7,mypath8])
planetnames = np.array(['The Sun', 'Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus','Neptun'])
fsize = 25
def read_files(path):  
    
    x, y, z = [],[],[]
    vx, vy, vz = [],[],[]
    
    

    with open(path, 'r') as infile:
        lines = infile.readlines()[2:]
        for line in lines:

            line = line.split()
            x.append(float(line[1]))
            y.append(float(line[2]))
            z.append(float(line[3]))
            vx.append(float(line[4]))
            vy.append(float(line[5]))
            vz.append(float(line[6]))
    
    r = np.zeros((len(x), 3))
    v = np.zeros((len(x), 3))
    for i in range(len(x)):
        r[i] = [x[i], y[i], z[i]]
        v[i] = [vx[i], vy[i], vz[i]]
        
    return r, v


fig = plt.figure(figsize = (20,15))
ax = plt.axes(projection='3d')

idx = -1


ax.scatter3D(0,0,0, s = 50, c = 'orange', label = 'The sun')

for i in range(len(pathlist)-1):
    i = i+1
    print(pathlist[i])
    r0, v0 = read_files(pathlist[i])
    xline = r0[:idx,0]
    yline = r0[:idx,1]
    zline = r0[:idx,2]
    ax.plot3D(xline, yline, zline, ms = 25,label = planetnames[i])


#ax.set_xlim([-10,10])
#ax.set_ylim([-10,10])
#ax.set_zlim([-10,10])

plt.title('The Solar System', pad = 50, fontsize = fsize+ 10)
ax.set_xlabel('X [AU]', fontsize = fsize)
ax.set_ylabel('Y [AU]',  fontsize = fsize)
ax.set_zlabel('Z [AU]',  fontsize = fsize)
ax.xaxis.set_tick_params(labelsize=fsize-10, pad = 15)
ax.yaxis.set_tick_params(labelsize=fsize-10, pad = 15)
ax.zaxis.set_tick_params(labelsize=fsize-10, pad = 15)

plt.legend(fontsize = fsize, loc='center left', bbox_to_anchor=(1, 0.5))

ax.yaxis.labelpad=50
ax.xaxis.labelpad=40
ax.zaxis.labelpad=40


plt.savefig('../Paper/Figures/5FFullSystem.png', bbox_inches='tight')
# Out:
# /home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5F2/Planet_Mercury.txt
# /home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5F2/Planet_Venus.txt
# /home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5F2/Planet_Earth.txt
# /home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5F2/Planet_Mars.txt
# /home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5F1/Planet_Jupiter.txt
# /home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5F1/Planet_Saturn.txt
# /home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5F1/Planet_Uranus.txt
# /home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5F1/Planet_Netptun.txt

# %%
pathlist = np.array([mypath0,mypath1,mypath2,mypath3,mypath4])
planetnames = np.array(['The Sun', 'Mercury', 'Venus', 'Earth', 'Mars'])
fsize = 25
def read_files(path):  
    
    x, y, z = [],[],[]
    vx, vy, vz = [],[],[]
    
    

    with open(path, 'r') as infile:
        lines = infile.readlines()[2:]
        for line in lines:

            line = line.split()
            x.append(float(line[1]))
            y.append(float(line[2]))
            z.append(float(line[3]))
            vx.append(float(line[4]))
            vy.append(float(line[5]))
            vz.append(float(line[6]))
    
    r = np.zeros((len(x), 3))
    v = np.zeros((len(x), 3))
    for i in range(len(x)):
        r[i] = [x[i], y[i], z[i]]
        v[i] = [vx[i], vy[i], vz[i]]
        
    return r, v


fig = plt.figure(figsize = (20,15))
ax = plt.axes(projection='3d')

idx = -1


ax.scatter3D(0,0,0, s = 50, c = 'orange', label = 'The sun')

for i in range(len(pathlist)-1):
    i = i+1
    print(pathlist[i])
    r0, v0 = read_files(pathlist[i])
    xline = r0[:idx,0]
    yline = r0[:idx,1]
    zline = r0[:idx,2]
    ax.plot3D(xline, yline, zline, ms = 25,label = planetnames[i])


#ax.set_xlim([-10,10])
#ax.set_ylim([-10,10])
#ax.set_zlim([-10,10])

plt.title('The Inner Solar System', pad = 50, fontsize = fsize+ 10)
ax.set_xlabel('X [AU]', fontsize = fsize)
ax.set_ylabel('Y [AU]',  fontsize = fsize)
ax.set_zlabel('Z [AU]',  fontsize = fsize)
ax.xaxis.set_tick_params(labelsize=fsize-10, pad = 15)
ax.yaxis.set_tick_params(labelsize=fsize-10, pad = 15)
ax.zaxis.set_tick_params(labelsize=fsize-10, pad = 15)

plt.legend(fontsize = fsize, loc='center left', bbox_to_anchor=(1, 0.5))

ax.yaxis.labelpad=50
ax.xaxis.labelpad=40
ax.zaxis.labelpad=40


plt.savefig('../Paper/Figures/5FFullSystem_inner.png', bbox_inches='tight')
# Out:
# /home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5F2/Planet_Mercury.txt
# /home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5F2/Planet_Venus.txt
# /home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5F2/Planet_Earth.txt
# /home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5F2/Planet_Mars.txt

# %%
mypath0                  = "/home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5F_threebody/Planet_Sun.txt"
mypath3                  = "/home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5F_threebody/Planet_Earth.txt"
mypath5                  = "/home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5F_threebody/Planet_Jupiter.txt"


pathlist = np.array([mypath0,mypath3,mypath5])
planetnames = np.array(['The Sun', 'Earth',  'Jupiter'])
fsize = 25
def read_files(path):  
    
    x, y, z = [],[],[]
    vx, vy, vz = [],[],[]
    
    

    with open(path, 'r') as infile:
        lines = infile.readlines()[2:]
        for line in lines:

            line = line.split()
            x.append(float(line[1]))
            y.append(float(line[2]))
            z.append(float(line[3]))
            vx.append(float(line[4]))
            vy.append(float(line[5]))
            vz.append(float(line[6]))
    
    r = np.zeros((len(x), 3))
    v = np.zeros((len(x), 3))
    for i in range(len(x)):
        r[i] = [x[i], y[i], z[i]]
        v[i] = [vx[i], vy[i], vz[i]]
        
    return r, v


fig = plt.figure(figsize = (20,15))
ax = plt.axes(projection='3d')

idx = -1


ax.scatter3D(0,0,0, s = 50, c = 'orange', label = 'The sun')

for i in range(len(pathlist)-1):
    i = i+1
    print(pathlist[i])
    r0, v0 = read_files(pathlist[i])
    xline = r0[:idx,0]
    yline = r0[:idx,1]
    zline = r0[:idx,2]
    ax.plot3D(xline, yline, zline, ms = 25,label = planetnames[i])


#ax.set_xlim([-10,10])
#ax.set_ylim([-10,10])
#ax.set_zlim([-10,10])

plt.title('The 3-Body Problem', pad = 50, fontsize = fsize+ 10)
ax.set_xlabel('X [AU]', fontsize = fsize)
ax.set_ylabel('Y [AU]',  fontsize = fsize)
ax.set_zlabel('Z [AU]',  fontsize = fsize)
ax.xaxis.set_tick_params(labelsize=fsize-10, pad = 15)
ax.yaxis.set_tick_params(labelsize=fsize-10, pad = 15)
ax.zaxis.set_tick_params(labelsize=fsize-10, pad = 15)

plt.legend(fontsize = fsize, loc='center left', bbox_to_anchor=(1, 0.5))

ax.yaxis.labelpad=50
ax.xaxis.labelpad=40
ax.zaxis.labelpad=40


plt.savefig('../Paper/Figures/5FThreeBody.png', bbox_inches='tight')
# Out:
# /home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5F_threebody/Planet_Earth.txt
# /home/oline/Documents/UiO/FYS3150/FYS3150/Project_5/Results/5F_threebody/Planet_Jupiter.txt
